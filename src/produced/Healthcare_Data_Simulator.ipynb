# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishikesh-Mate/RealTime-Healthcare-Data-Pipeline/blob/main/Healthcare_Data_Simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
from datetime import datetime

# This function creates ONE fake medical record
def generate_patient_data():
    patient_ids = ["P-101", "P-102", "P-103", "P-104", "P-105"]

    record = {
        "patient_id": random.choice(patient_ids),
        "heart_rate": random.randint(60, 110),      # Normal to slightly high
        "spo2": random.randint(90, 100),            # Blood oxygen level
        "temperature": round(random.uniform(97.0, 103.0), 1),
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }
    return record

# This loop runs the simulator
print("Starting Patient Vitals Stream... (Press 'Stop' button to end)")

while True:
    # Simulate a "batch" of 5 patients every 3 seconds
    for _ in range(5):
        data = generate_patient_data()
        print(data)

    print("-" * 30) # A separator to show the "burst"
    time.sleep(3)
# Out:
# Starting Patient Vitals Stream... (Press 'Stop' button to end)
# {'patient_id': 'P-104', 'heart_rate': 108, 'spo2': 99, 'temperature': 97.7, 'timestamp': '2026-03-09 04:51:36'}
# {'patient_id': 'P-101', 'heart_rate': 89, 'spo2': 99, 'temperature': 99.9, 'timestamp': '2026-03-09 04:51:36'}
# {'patient_id': 'P-102', 'heart_rate': 101, 'spo2': 92, 'temperature': 97.1, 'timestamp': '2026-03-09 04:51:36'}
# {'patient_id': 'P-101', 'heart_rate': 62, 'spo2': 91, 'temperature': 102.6, 'timestamp': '2026-03-09 04:51:36'}
# {'patient_id': 'P-103', 'heart_rate': 84, 'spo2': 96, 'temperature': 102.8, 'timestamp': '2026-03-09 04:51:36'}
# ------------------------------
# {'patient_id': 'P-102', 'heart_rate': 99, 'spo2': 99, 'temperature': 99.2, 'timestamp': '2026-03-09 04:51:39'}
# {'patient_id': 'P-105', 'heart_rate': 74, 'spo2': 92, 'temperature': 98.3, 'timestamp': '2026-03-09 04:51:39'}
# {'patient_id': 'P-102', 'heart_rate': 96, 'spo2': 90, 'temperature': 101.4, 'timestamp': '2026-03-09 04:51:39'}
# {'patient_id': 'P-103', 'heart_rate': 83, 'spo2': 90, 'temperature': 97.7, 'timestamp': '2026-03-09 04:51:39'}
# {'patient_id': 'P-105', 'heart_rate': 103, 'spo2': 95, 'temperature': 102.8, 'timestamp': '2026-03-09 04:51:39'}
# ------------------------------
# {'patient_id': 'P-101', 'heart_rate': 74, 'spo2': 99, 'temperature': 101.3, 'timestamp': '2026-03-09 04:51:42'}
# {'patient_id': 'P-103', 'heart_rate': 96, 'spo2': 94, 'temperature': 101.0, 'timestamp': '2026-03-09 04:51:42'}
# {'patient_id': 'P-101', 'heart_rate': 75, 'spo2': 96, 'temperature': 102.2, 'timestamp': '2026-03-09 04:51:42'}
# {'patient_id': 'P-103', 'heart_rate': 60, 'spo2': 90, 'temperature': 97.4, 'timestamp': '2026-03-09 04:51:42'}
# {'patient_id': 'P-105', 'heart_rate': 63, 'spo2': 91, 'temperature': 100.1, 'timestamp': '2026-03-09 04:51:42'}
# ------------------------------
# {'patient_id': 'P-101', 'heart_rate': 101, 'spo2': 100, 'temperature': 98.8, 'timestamp': '2026-03-09 04:51:45'}
# {'patient_id': 'P-104', 'heart_rate': 79, 'spo2': 99, 'temperature': 102.6, 'timestamp': '2026-03-09 04:51:45'}
# {'patient_id': 'P-104', 'heart_rate': 65, 'spo2': 100, 'temperature': 102.2, 'timestamp': '2026-03-09 04:51:45'}
# {'patient_id': 'P-101', 'heart_rate': 84, 'spo2': 92, 'temperature': 101.6, 'timestamp': '2026-03-09 04:51:45'}
# {'patient_id': 'P-104', 'heart_rate': 106, 'spo2': 94, 'temperature': 98.1, 'timestamp': '2026-03-09 04:51:45'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 102, 'spo2': 96, 'temperature': 98.6, 'timestamp': '2026-03-09 04:51:48'}
# {'patient_id': 'P-104', 'heart_rate': 92, 'spo2': 94, 'temperature': 100.6, 'timestamp': '2026-03-09 04:51:48'}
# {'patient_id': 'P-105', 'heart_rate': 86, 'spo2': 95, 'temperature': 99.5, 'timestamp': '2026-03-09 04:51:48'}
# {'patient_id': 'P-105', 'heart_rate': 62, 'spo2': 100, 'temperature': 101.5, 'timestamp': '2026-03-09 04:51:48'}
# {'patient_id': 'P-105', 'heart_rate': 85, 'spo2': 94, 'temperature': 98.0, 'timestamp': '2026-03-09 04:51:48'}
# ------------------------------
# {'patient_id': 'P-101', 'heart_rate': 80, 'spo2': 99, 'temperature': 102.8, 'timestamp': '2026-03-09 04:51:51'}
# {'patient_id': 'P-104', 'heart_rate': 101, 'spo2': 90, 'temperature': 99.9, 'timestamp': '2026-03-09 04:51:51'}
# {'patient_id': 'P-105', 'heart_rate': 98, 'spo2': 97, 'temperature': 99.5, 'timestamp': '2026-03-09 04:51:51'}
# {'patient_id': 'P-103', 'heart_rate': 99, 'spo2': 95, 'temperature': 98.5, 'timestamp': '2026-03-09 04:51:51'}
# {'patient_id': 'P-102', 'heart_rate': 82, 'spo2': 97, 'temperature': 99.4, 'timestamp': '2026-03-09 04:51:51'}
# ------------------------------
# {'patient_id': 'P-102', 'heart_rate': 65, 'spo2': 96, 'temperature': 101.2, 'timestamp': '2026-03-09 04:51:54'}
# {'patient_id': 'P-104', 'heart_rate': 87, 'spo2': 96, 'temperature': 101.4, 'timestamp': '2026-03-09 04:51:54'}
# {'patient_id': 'P-102', 'heart_rate': 103, 'spo2': 97, 'temperature': 98.3, 'timestamp': '2026-03-09 04:51:54'}
# {'patient_id': 'P-104', 'heart_rate': 81, 'spo2': 100, 'temperature': 102.1, 'timestamp': '2026-03-09 04:51:54'}
# {'patient_id': 'P-102', 'heart_rate': 100, 'spo2': 98, 'temperature': 102.9, 'timestamp': '2026-03-09 04:51:54'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 101, 'spo2': 93, 'temperature': 98.8, 'timestamp': '2026-03-09 04:51:57'}
# {'patient_id': 'P-104', 'heart_rate': 68, 'spo2': 100, 'temperature': 98.2, 'timestamp': '2026-03-09 04:51:57'}
# {'patient_id': 'P-103', 'heart_rate': 85, 'spo2': 90, 'temperature': 102.7, 'timestamp': '2026-03-09 04:51:57'}
# {'patient_id': 'P-103', 'heart_rate': 101, 'spo2': 96, 'temperature': 99.5, 'timestamp': '2026-03-09 04:51:57'}
# {'patient_id': 'P-102', 'heart_rate': 103, 'spo2': 97, 'temperature': 102.5, 'timestamp': '2026-03-09 04:51:57'}
# ------------------------------
# {'patient_id': 'P-103', 'heart_rate': 96, 'spo2': 100, 'temperature': 102.2, 'timestamp': '2026-03-09 04:52:00'}
# {'patient_id': 'P-104', 'heart_rate': 91, 'spo2': 97, 'temperature': 98.7, 'timestamp': '2026-03-09 04:52:00'}
# {'patient_id': 'P-102', 'heart_rate': 90, 'spo2': 97, 'temperature': 101.8, 'timestamp': '2026-03-09 04:52:00'}
# {'patient_id': 'P-101', 'heart_rate': 86, 'spo2': 93, 'temperature': 101.3, 'timestamp': '2026-03-09 04:52:00'}
# {'patient_id': 'P-101', 'heart_rate': 69, 'spo2': 97, 'temperature': 98.6, 'timestamp': '2026-03-09 04:52:00'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 68, 'spo2': 95, 'temperature': 98.1, 'timestamp': '2026-03-09 04:52:03'}
# {'patient_id': 'P-105', 'heart_rate': 64, 'spo2': 90, 'temperature': 99.6, 'timestamp': '2026-03-09 04:52:03'}
# {'patient_id': 'P-105', 'heart_rate': 75, 'spo2': 96, 'temperature': 100.2, 'timestamp': '2026-03-09 04:52:03'}
# {'patient_id': 'P-103', 'heart_rate': 99, 'spo2': 100, 'temperature': 97.6, 'timestamp': '2026-03-09 04:52:03'}
# {'patient_id': 'P-102', 'heart_rate': 93, 'spo2': 97, 'temperature': 97.7, 'timestamp': '2026-03-09 04:52:03'}
# ------------------------------
# {'patient_id': 'P-102', 'heart_rate': 92, 'spo2': 98, 'temperature': 102.6, 'timestamp': '2026-03-09 04:52:06'}
# {'patient_id': 'P-101', 'heart_rate': 100, 'spo2': 94, 'temperature': 98.8, 'timestamp': '2026-03-09 04:52:06'}
# {'patient_id': 'P-102', 'heart_rate': 82, 'spo2': 92, 'temperature': 102.9, 'timestamp': '2026-03-09 04:52:06'}
# {'patient_id': 'P-102', 'heart_rate': 92, 'spo2': 91, 'temperature': 97.7, 'timestamp': '2026-03-09 04:52:06'}
# {'patient_id': 'P-103', 'heart_rate': 107, 'spo2': 93, 'temperature': 101.9, 'timestamp': '2026-03-09 04:52:06'}
# ------------------------------
# {'patient_id': 'P-101', 'heart_rate': 67, 'spo2': 100, 'temperature': 98.3, 'timestamp': '2026-03-09 04:52:09'}
# {'patient_id': 'P-102', 'heart_rate': 89, 'spo2': 98, 'temperature': 102.6, 'timestamp': '2026-03-09 04:52:09'}
# {'patient_id': 'P-101', 'heart_rate': 108, 'spo2': 92, 'temperature': 98.0, 'timestamp': '2026-03-09 04:52:09'}
# {'patient_id': 'P-102', 'heart_rate': 105, 'spo2': 96, 'temperature': 97.0, 'timestamp': '2026-03-09 04:52:09'}
# {'patient_id': 'P-104', 'heart_rate': 85, 'spo2': 95, 'temperature': 102.8, 'timestamp': '2026-03-09 04:52:09'}
# ------------------------------
# {'patient_id': 'P-101', 'heart_rate': 104, 'spo2': 93, 'temperature': 102.0, 'timestamp': '2026-03-09 04:52:12'}
# {'patient_id': 'P-104', 'heart_rate': 95, 'spo2': 97, 'temperature': 102.1, 'timestamp': '2026-03-09 04:52:12'}
# {'patient_id': 'P-102', 'heart_rate': 88, 'spo2': 99, 'temperature': 99.1, 'timestamp': '2026-03-09 04:52:12'}
# {'patient_id': 'P-101', 'heart_rate': 66, 'spo2': 100, 'temperature': 100.8, 'timestamp': '2026-03-09 04:52:12'}
# {'patient_id': 'P-105', 'heart_rate': 100, 'spo2': 95, 'temperature': 99.7, 'timestamp': '2026-03-09 04:52:12'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 81, 'spo2': 97, 'temperature': 97.7, 'timestamp': '2026-03-09 04:52:15'}
# {'patient_id': 'P-102', 'heart_rate': 85, 'spo2': 95, 'temperature': 97.0, 'timestamp': '2026-03-09 04:52:15'}
# {'patient_id': 'P-103', 'heart_rate': 100, 'spo2': 95, 'temperature': 98.8, 'timestamp': '2026-03-09 04:52:15'}
# {'patient_id': 'P-102', 'heart_rate': 104, 'spo2': 100, 'temperature': 98.6, 'timestamp': '2026-03-09 04:52:15'}
# {'patient_id': 'P-102', 'heart_rate': 103, 'spo2': 100, 'temperature': 100.5, 'timestamp': '2026-03-09 04:52:15'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 98, 'spo2': 91, 'temperature': 102.7, 'timestamp': '2026-03-09 04:52:18'}
# {'patient_id': 'P-101', 'heart_rate': 63, 'spo2': 92, 'temperature': 102.0, 'timestamp': '2026-03-09 04:52:18'}
# {'patient_id': 'P-102', 'heart_rate': 66, 'spo2': 93, 'temperature': 97.6, 'timestamp': '2026-03-09 04:52:18'}
# {'patient_id': 'P-103', 'heart_rate': 61, 'spo2': 95, 'temperature': 101.5, 'timestamp': '2026-03-09 04:52:18'}
# {'patient_id': 'P-101', 'heart_rate': 96, 'spo2': 94, 'temperature': 102.9, 'timestamp': '2026-03-09 04:52:18'}
# ------------------------------
# {'patient_id': 'P-101', 'heart_rate': 85, 'spo2': 97, 'temperature': 101.3, 'timestamp': '2026-03-09 04:52:21'}
# {'patient_id': 'P-102', 'heart_rate': 103, 'spo2': 94, 'temperature': 98.2, 'timestamp': '2026-03-09 04:52:21'}
# {'patient_id': 'P-101', 'heart_rate': 66, 'spo2': 96, 'temperature': 102.2, 'timestamp': '2026-03-09 04:52:21'}
# {'patient_id': 'P-104', 'heart_rate': 101, 'spo2': 95, 'temperature': 100.7, 'timestamp': '2026-03-09 04:52:21'}
# {'patient_id': 'P-102', 'heart_rate': 97, 'spo2': 93, 'temperature': 100.2, 'timestamp': '2026-03-09 04:52:21'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 64, 'spo2': 92, 'temperature': 99.6, 'timestamp': '2026-03-09 04:52:24'}
# {'patient_id': 'P-105', 'heart_rate': 84, 'spo2': 98, 'temperature': 97.9, 'timestamp': '2026-03-09 04:52:24'}
# {'patient_id': 'P-101', 'heart_rate': 104, 'spo2': 92, 'temperature': 100.3, 'timestamp': '2026-03-09 04:52:24'}
# {'patient_id': 'P-104', 'heart_rate': 84, 'spo2': 98, 'temperature': 100.1, 'timestamp': '2026-03-09 04:52:24'}
# {'patient_id': 'P-103', 'heart_rate': 98, 'spo2': 100, 'temperature': 102.6, 'timestamp': '2026-03-09 04:52:24'}
# ------------------------------
# {'patient_id': 'P-103', 'heart_rate': 81, 'spo2': 91, 'temperature': 100.1, 'timestamp': '2026-03-09 04:52:27'}
# {'patient_id': 'P-102', 'heart_rate': 106, 'spo2': 93, 'temperature': 99.3, 'timestamp': '2026-03-09 04:52:27'}
# {'patient_id': 'P-105', 'heart_rate': 66, 'spo2': 100, 'temperature': 99.2, 'timestamp': '2026-03-09 04:52:27'}
# {'patient_id': 'P-104', 'heart_rate': 89, 'spo2': 95, 'temperature': 100.1, 'timestamp': '2026-03-09 04:52:27'}
# {'patient_id': 'P-101', 'heart_rate': 67, 'spo2': 100, 'temperature': 101.3, 'timestamp': '2026-03-09 04:52:27'}
# ------------------------------
# {'patient_id': 'P-104', 'heart_rate': 74, 'spo2': 95, 'temperature': 100.5, 'timestamp': '2026-03-09 04:52:30'}
# {'patient_id': 'P-105', 'heart_rate': 70, 'spo2': 98, 'temperature': 101.8, 'timestamp': '2026-03-09 04:52:30'}
# {'patient_id': 'P-105', 'heart_rate': 62, 'spo2': 98, 'temperature': 99.0, 'timestamp': '2026-03-09 04:52:30'}
# {'patient_id': 'P-101', 'heart_rate': 80, 'spo2': 93, 'temperature': 102.9, 'timestamp': '2026-03-09 04:52:30'}
# {'patient_id': 'P-105', 'heart_rate': 68, 'spo2': 97, 'temperature': 97.1, 'timestamp': '2026-03-09 04:52:30'}
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_337/100009551.py in <cell line: 0>()
#      26
#      27     print("-" * 30) # A separator to show the "burst"
# ---> 28     time.sleep(3)
#
# KeyboardInterrupt:
